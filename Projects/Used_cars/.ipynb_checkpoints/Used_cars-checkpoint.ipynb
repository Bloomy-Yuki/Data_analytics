# %% [markdown]
# ## Notebook for Used cars in germany  [Kaggle Dataset](https://www.kaggle.com/datasets/wspirat/germany-used-cars-dataset-2023)
# ### 1. General Idea
# ---
# from the kaggle link, we can see that the dataset is mostly clean, we still need to clean it a little before fetching
# it to the visualization tool, namely Tableau.

# %%
#loading the tidyverse
library(tidyverse)
library(janitor)

#loading the .csv file into the dataframe
car_df <- read.csv("Files/car_data.csv")
# Out:
# ── Attaching core tidyverse packages ──────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.0     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attache Paket: 'janitor'
#
#
# Die folgenden Objekte sind maskiert von 'package:stats':
#
#     chisq.test, fisher.test

# %% [markdown]
# ### 2. chosing our columns
# ---
# the columns that we care about are mainly : brand, model, color, year, price_in_euro, transmission_type, fuel_type, fuel_consumption_l_100km, mileage_in_km. loading that into dummy datafram and cleaning it is our main objective.

# %%
#choosing the colomns that we need in our dashboard
car <- car_df[c('num', 'brand', 'model','color','year','price_in_euro','transmission_type','fuel_type','fuel_consumption_l_100km', 'mileage_in_km')]

#using car2 as dummy variable to store cleaning codes on car variable
car2 <- car

# %%
#filtering columns after checking their unique values and noticing that their values has errors

#filtering year in only the range
car2 <- car2 %>% filter( as.integer((year)) %in% c((1995:2023)  ) )

#filtering the fuel type to the main ones
car2 <- car2 %>% filter( fuel_type %in% c("Petrol", "Diesel", "Hybrid", "Electric")  )

#getting only known transmission types
car2 <- car2 %>% filter( transmission_type != "Unknown"  ) 

#filtering the consumption to the results that have dimensional inits
car2 <- car2 %>% filter( grepl("l/100 km", fuel_consumption_l_100km ) == TRUE)


car2
# Out:
# Warning message:
# "There was 1 warning in `filter()`.
# ℹ In argument: `as.integer((year)) %in% c((1995:2023))`.
# Caused by warning in `as.integer((year)) %in% c((1995:2023))`:
# ! NAs durch Umwandlung erzeugt"
#        num    brand      model                   color  year price_in_euro
# 1       0     alfa-romeo Alfa Romeo GTV          red    1995 1300
# 2       3     alfa-romeo Alfa Romeo Spider       black  1995 4900
# 3       4     alfa-romeo Alfa Romeo 164          red    1996 17950
# 4       5     alfa-romeo Alfa Romeo Spider       red    1996 7900
# 5       6     alfa-romeo Alfa Romeo 145          red    1996 3500
# 6       7     alfa-romeo Alfa Romeo 164          black  1996 5500
# 7       8     alfa-romeo Alfa Romeo Spider       black  1996 8990
# 8       9     alfa-romeo Alfa Romeo Spider       black  1996 6976
# 9      10     alfa-romeo Alfa Romeo Spider       silver 1996 5499
# 10     11     alfa-romeo Alfa Romeo Spider       silver 1996 8499
# 11     12     alfa-romeo Alfa Romeo GTV          silver 1996 2290
# 12     13     alfa-romeo Alfa Romeo GTV          grey   1997 15800
# 13     14     alfa-romeo Alfa Romeo 155          grey   1997 7950
# 14     15     alfa-romeo Alfa Romeo GTV          red    1997 1300
# 15     16     alfa-romeo Alfa Romeo GTV          red    1997 6900
# 16     17     alfa-romeo Alfa Romeo GTV          red    1997 16900
# 3      Manual            Petrol    7,2 l/100 km              96127
# 4      Manual            Petrol    9,5 l/100 km              47307
# 5      Manual            Petrol    8,8 l/100 km             230000
# 6      Manual            Petrol    13,4 l/100 km            168000
# 7      Manual            Petrol    11 l/100 km              168600
# 8      Manual            Petrol    9,2 l/100 km              99000
# 9      Manual            Petrol    11,1 l/100 km            157000
# 10     Manual            Petrol    9,5 l/100 km              15550
# 11     Manual            Petrol    9,5 l/100 km             333500
# 12     Manual            Petrol    11,7 l/100 km            177000
# 13     Manual            Petrol    8,4 l/100 km             101726
# 14     Manual            Petrol    10,9 l/100 km            178000
# 15     Manual            Petrol    9,2 l/100 km             110313
# 16     Manual            Petrol    11,7 l/100 km            174000
# 17     Manual            Petrol    8,2 l/100 km             124963
# 18     Manual            Petrol    9,2 l/100 km              39000
# 19     Manual            Petrol    9,5 l/100 km             124112
# 20     Manual            Petrol    11,7 l/100 km            125000
# 21     Manual            Petrol    9,5 l/100 km             130900
# 22     Manual            Petrol    9,5 l/100 km             138000
# 23     Manual            Petrol    8,4 l/100 km             199000
# 24     Manual            Petrol    9,5 l/100 km             192000
# 25     Manual            Petrol    11,1 l/100 km            140000
# 26     Manual            Petrol    9,2 l/100 km             149500
# 27     Manual            Petrol    9,2 l/100 km             132000
# 28     Manual            Petrol    8,9 l/100 km                133
# 29     Manual            Petrol    8,9 l/100 km              65000
# 30     Manual            Petrol    9,5 l/100 km             224000
# ⋮      ⋮                 ⋮         ⋮                        ⋮
# 220597 Automatic         Petrol    6,7 l/100 km             1500
# 220598 Automatic         Diesel    5,6 l/100 km                9
# 220599 Automatic         Diesel    6,3 l/100 km             1096
# 220600 Automatic         Petrol    7,9 l/100 km             2500
# 220601 Automatic         Diesel    5,3 l/100 km             2500
# 220602 Automatic         Diesel    7,2 l/100 km             2000
# 220603 Automatic         Diesel    4,7 l/100 km               10
# 220604 Automatic         Hybrid    7,9 l/100 km               50
# 220605 Automatic         Diesel    4,7 l/100 km               10
# 220606 Automatic         Petrol    7 l/100 km               6044
# 220607 Automatic         Diesel    5,6 l/100 km             3776
# 220608 Automatic         Diesel    5,6 l/100 km             5050
# 220609 Automatic         Petrol    6,6 l/100 km             2328
# 220610 Automatic         Diesel    5,6 l/100 km             6235
# 220611 Automatic         Diesel    5,6 l/100 km             6235
# 220612 Automatic         Petrol    6,6 l/100 km             2182
# 220613 Automatic         Petrol    6,3 l/100 km             6047
# 220614 Automatic         Diesel    4,7 l/100 km                7
# 220615 Automatic         Diesel    5,7 l/100 km              100
# 220616 Automatic         Petrol    6,6 l/100 km             2145
# 220617 Automatic         Diesel    5,5 l/100 km               50
# 220618 Automatic         Diesel    5,6 l/100 km             9900
# 220619 Automatic         Petrol    6,7 l/100 km             2100
# 220620 Automatic         Diesel    5,5 l/100 km             2500
# 220621 Automatic         Diesel    6,5 l/100 km             1506
# 220622 Automatic         Hybrid    7,4 l/100 km               60
# 220623 Automatic         Diesel    5,6 l/100 km             5000
# 220624 Automatic         Diesel    5,6 l/100 km             5900
# 220625 Automatic         Diesel    7,6 l/100 km             4900
# 220626 Automatic         Diesel    4,7 l/100 km             1531

# %%
# removing empty values

car2 <- subset(car2, num != "" )
car2 <- subset(car2, brand != "" )
car2 <- subset(car2, model != "" )
car2 <- subset(car2, color != "" )
car2 <- subset(car2, year != "" )
car2 <- subset(car2, price_in_euro != "" )
car2 <- subset(car2, transmission_type != "" )
car2 <- subset(car2, fuel_type != "" )
car2 <- subset(car2, fuel_consumption_l_100km != "" )
car2 <- subset(car2, mileage_in_km != "" )

car2
# Out:
#        num    brand      model                   color  year price_in_euro
# 1       0     alfa-romeo Alfa Romeo GTV          red    1995 1300
# 2       3     alfa-romeo Alfa Romeo Spider       black  1995 4900
# 3       4     alfa-romeo Alfa Romeo 164          red    1996 17950
# 4       5     alfa-romeo Alfa Romeo Spider       red    1996 7900
# 5       6     alfa-romeo Alfa Romeo 145          red    1996 3500
# 6       7     alfa-romeo Alfa Romeo 164          black  1996 5500
# 7       8     alfa-romeo Alfa Romeo Spider       black  1996 8990
# 8       9     alfa-romeo Alfa Romeo Spider       black  1996 6976
# 9      10     alfa-romeo Alfa Romeo Spider       silver 1996 5499
# 10     11     alfa-romeo Alfa Romeo Spider       silver 1996 8499
# 11     12     alfa-romeo Alfa Romeo GTV          silver 1996 2290
# 12     13     alfa-romeo Alfa Romeo GTV          grey   1997 15800
# 13     14     alfa-romeo Alfa Romeo 155          grey   1997 7950
# 14     15     alfa-romeo Alfa Romeo GTV          red    1997 1300
# 15     16     alfa-romeo Alfa Romeo GTV          red    1997 6900
# 16     17     alfa-romeo Alfa Romeo GTV          red    1997 16900
# 17     19     alfa-romeo Alfa Romeo 145          red    1997 11990
# 18     20     alfa-romeo Alfa Romeo Spider       red    1997 11900
# 19     21     alfa-romeo Alfa Romeo Spider       red    1997 5800
# 20     23     alfa-romeo Alfa Romeo GTV          black  1997 5777
# 21     24     alfa-romeo Alfa Romeo Spider       black  1997 2500
# 22     25     alfa-romeo Alfa Romeo Spider       black  1997 3000
# 23     26     alfa-romeo Alfa Romeo 146          black  1997 1450
# 24     28     alfa-romeo Alfa Romeo Spider       silver 1997 4650
# 25     29     alfa-romeo Alfa Romeo Spider       white  1997 11949
# 26     30     alfa-romeo Alfa Romeo GTV          beige  1998 2699
# 27     31     alfa-romeo Alfa Romeo Spider       grey   1998 6999
# 28     32     alfa-romeo Alfa Romeo 156          red    1998 4000
# 29     33     alfa-romeo Alfa Romeo Spider       black  1998 8450
# 30     34     alfa-romeo Alfa Romeo Spider       black  1998 3500
# ⋮      ⋮      ⋮          ⋮                       ⋮      ⋮    ⋮
# 21     Manual            Petrol    9,5 l/100 km             130900
# 22     Manual            Petrol    9,5 l/100 km             138000
# 23     Manual            Petrol    8,4 l/100 km             199000
# 24     Manual            Petrol    9,5 l/100 km             192000
# 25     Manual            Petrol    11,1 l/100 km            140000
# 26     Manual            Petrol    9,2 l/100 km             149500
# 27     Manual            Petrol    9,2 l/100 km             132000
# 28     Manual            Petrol    8,9 l/100 km                133
# 29     Manual            Petrol    8,9 l/100 km              65000
# 30     Manual            Petrol    9,5 l/100 km             224000
# ⋮      ⋮                 ⋮         ⋮                        ⋮
# 220597 Automatic         Petrol    6,7 l/100 km             1500
# 220598 Automatic         Diesel    5,6 l/100 km                9
# 220599 Automatic         Diesel    6,3 l/100 km             1096
# 220600 Automatic         Petrol    7,9 l/100 km             2500
# 220601 Automatic         Diesel    5,3 l/100 km             2500
# 220602 Automatic         Diesel    7,2 l/100 km             2000
# 220603 Automatic         Diesel    4,7 l/100 km               10
# 220604 Automatic         Hybrid    7,9 l/100 km               50
# 220605 Automatic         Diesel    4,7 l/100 km               10
# 220606 Automatic         Petrol    7 l/100 km               6044
# 220607 Automatic         Diesel    5,6 l/100 km             3776
# 220608 Automatic         Diesel    5,6 l/100 km             5050
# 220609 Automatic         Petrol    6,6 l/100 km             2328
# 220610 Automatic         Diesel    5,6 l/100 km             6235
# 220611 Automatic         Diesel    5,6 l/100 km             6235
# 220612 Automatic         Petrol    6,6 l/100 km             2182
# 220613 Automatic         Petrol    6,3 l/100 km             6047
# 220614 Automatic         Diesel    4,7 l/100 km                7
# 220615 Automatic         Diesel    5,7 l/100 km              100
# 220616 Automatic         Petrol    6,6 l/100 km             2145
# 220617 Automatic         Diesel    5,5 l/100 km               50
# 220618 Automatic         Diesel    5,6 l/100 km             9900
# 220619 Automatic         Petrol    6,7 l/100 km             2100
# 220620 Automatic         Diesel    5,5 l/100 km             2500
# 220621 Automatic         Diesel    6,5 l/100 km             1506
# 220622 Automatic         Hybrid    7,4 l/100 km               60
# 220623 Automatic         Diesel    5,6 l/100 km             5000
# 220624 Automatic         Diesel    5,6 l/100 km             5900
# 220625 Automatic         Diesel    7,6 l/100 km             4900
# 220626 Automatic         Diesel    4,7 l/100 km             1531

# %% [markdown]
# ### 3. saving the result
# ---
# after cleaning the data, we save it in the "Files" dictionary

# %%
write.csv(car2, "Files/Clean_car_data.csv")

# %%
#Python code
from IPython.display import display, HTML
display(HTML("Files/Dashboard_link.html"))
# Out:
# <html>
#     <div class='tableauPlaceholder' id='viz1714941191016' style='position: relative'><noscript><a href='#'><img alt='Dashboard 2 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Us&#47;UsedcarsinGermanythedatavisualized&#47;Dashboard2&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='site_root' value='' /><param name='name' value='UsedcarsinGermanythedatavisualized&#47;Dashboard2' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Us&#47;UsedcarsinGermanythedatavisualized&#47;Dashboard2&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-GB' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1714941191016');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='1400px';vizElement.style.height='1227px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# </html>
